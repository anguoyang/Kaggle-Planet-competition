# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
import os

# %%
imgs = os.listdir('./test-jpg-additional')
d = 'C:\\Users\\LR2214\\Desktop\\kaggle\\amazon\\test-jpg-additional\\'

# %%
for i in range(len(imgs)):
    im = Image.open(d + imgs[i])
    im.thumbnail((32,32))
    im.save('./test-jpg-additional_mini/' + imgs[i])


# plt.imread(d + imgs[1])

# %%
pwd
# Out:
# 'C:\\Users\\LR2214'

# %%
plt.imshow(out)
plt.show()

# %%
a = Image.open(d+imgs[3])

# %%
a.resize((32,32))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk, check)
#     696     try:
# --> 697         rawmode, mode = _OUTMODES[mode]
#     698     except KeyError:
#
# KeyError: 'CMYK'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     309             method = get_real_method(obj, self.print_method)
#     310             if method is not None:
# --> 311                 return method()
#     312             return None
#     313         else:
#
# C:\Anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     624         from io import BytesIO
#     625         b = BytesIO()
# ...

# %%
a.save('./train-jpg_mini/dsds.jpg')

# %%
plt.imshow(a)
plt.show()

# %%
a.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-74befb814698> in <module>()
# ----> 1 a.shape
#
# AttributeError: 'JpegImageFile' object has no attribute 'shape'
